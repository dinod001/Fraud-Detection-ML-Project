# %% [markdown]
# ### 01. Import Dependecies

# %%
import pandas as pd

# %% [markdown]
# ### 02. Load Data

# %%
df = pd.read_csv("data/processed/outlier_handled.csv")
df.head()
# Out:
#    purchase_value source browser sex  age  class  account_age_minutes  \
# 0       -0.037037    SEO  Chrome   M   39      0            -0.076893
# 1       -0.703704    Ads  Chrome   F   53      0            -0.899342
# 2       -0.740741    SEO   Opera   M   53      1            -0.902629
# 3        0.333333    SEO  Safari   M   41      0            -0.812467
# 4        0.148148    Ads  Safari   M   45      0            -0.103501
#
#    device_count  user_count_per_device        country
# 0           0.0                    0.0          Japan
# 1           0.0                    0.0  United States
# 2          11.0                   11.0  United States
# 3           0.0                    0.0        Unknown
# 4           0.0                    0.0  United States

# %% [markdown]
# ### 03. Feature Binning

# %%
df['age'].describe()
# Out:
# count    151112.000000
# mean         33.140704
# std           8.617733
# min          18.000000
# 25%          27.000000
# 50%          33.000000
# 75%          39.000000
# max          76.000000
# Name: age, dtype: float64

# %%
def binning_age(age):
    if age >= 18 and age <= 25:
        return "Young"
    elif age >= 26 and age <= 35:
        return "Adult"
    elif age >= 36 and age <= 55:
        return "Middle-aged"
    elif age >= 56:
        return "Senior"
    else:
        return "Unknown"

# %%
df['age'] = df['age'].map(binning_age)

# %%
df.head(10)
# Out:
#    purchase_value source browser sex          age  class  account_age_minutes  \
# 0       -0.037037    SEO  Chrome   M  Middle-aged      0            -0.076893
# 1       -0.703704    Ads  Chrome   F  Middle-aged      0            -0.899342
# 2       -0.740741    SEO   Opera   M  Middle-aged      1            -0.902629
# 3        0.333333    SEO  Safari   M  Middle-aged      0            -0.812467
# 4        0.148148    Ads  Safari   M  Middle-aged      0            -0.103501
# 5        0.259259    Ads  Chrome   M        Young      0            -0.125585
# 6       -0.888889    Ads  Chrome   F        Young      0            -0.503598
# 7       -0.296296    Ads   Opera   M        Adult      0            -0.120492
# 8       -0.185185    SEO      IE   F  Middle-aged      0            -0.244082
# 9        1.000000    Ads      IE   M        Adult      0             0.003189
#
#    device_count  user_count_per_device        country
# 0           0.0                    0.0          Japan
# 1           0.0                    0.0  United States
# 2          11.0                   11.0  United States
# 3           0.0                    0.0        Unknown
# 4           0.0                    0.0  United States
# 5           0.0                    0.0         Canada
# 6           0.0                    0.0        Unknown
# 7           0.0                    0.0  United States
# 8           0.0                    0.0          China
# 9           0.0                    0.0  United States

# %% [markdown]
# ### 04. Saving Data

# %%
df.to_csv("data/processed/feature_binning.csv",index=False)
